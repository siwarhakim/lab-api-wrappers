# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize
from random import randint
from time import sleep

# %%
# 37i9dQZF1DWW668oFRU96k / 37i9dQZF1EQqA6klNdJvwx / 37i9dQZF1DX9sIqqvKsjG8 / 7olbuvhflc9xSMvGkGb78m / 37i9dQZF1DWXLeA8Omikj7 / 37i9dQZF1DXaXB8fQg7xif / 37i9dQZF1DX9sIqqvKsjG8 / 37i9dQZF1DWV7EzJMK2FUI / 37i9dQZF1DWZeKCadgRdKQ / 37i9dQZF1DX8NTLI2TtZa6 / 37i9dQZF1DWT7XSlwvR1ar / 37i9dQZF1DX8Uebhn9wzrS / 37i9dQZF1DX56qfiUZBncF / 37i9dQZF1DX8qqIDAkKiQg / 06HL4z0CvFAxyc27GXpf02 / 1Xyo4u8uXC1ZmMpatF05PJ / 6qqNVTkY8uBg9cP3Jd7DAH / 5DwaX2jFVl1RGpxBZiNHxf / 5hPXWJOGl0tLvXhvT6Pgz3/ 0Ncor000gD8vERjgIcjQ10 / 4JTrhcEuX81kdYbLFmjD2S /34rWwXE2GklNdRgWNb4muZ / 6KC1QBkP4LkOYakPKAo0UX / 4afyc6sH6wQEfTUksWzWai

# %%
#ll use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "6KC1QBkP4LkOYakPKAo0UX") 
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6KC1QBkP4LkOYakPKAo0UX/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-04-22T04:29:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12125655017'},
#     'href': 'https://api.spotify.com/v1/users/12125655017',
#     'id': '12125655017',
#     'type': 'user',
#     'uri': 'spotify:user:12125655017'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bd795be7032b63a14797fb981fbb059e20b4efbe?cid=f3c99daddfd34fcc9fcd8581e1a198f6',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
# ...

# %%
playlist["total"]
# Out:
# 3793

# %%
playlist['items']
# Out:
# [{'added_at': '2024-04-22T04:29:18Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12125655017'},
#    'href': 'https://api.spotify.com/v1/users/12125655017',
#    'id': '12125655017',
#    'type': 'user',
#    'uri': 'spotify:user:12125655017'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/bd795be7032b63a14797fb981fbb059e20b4efbe?cid=f3c99daddfd34fcc9fcd8581e1a198f6',
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
# ...

# %%
all_tracks = get_playlist_tracks("6KC1QBkP4LkOYakPKAo0UX")
len(all_tracks)
# Out:
# 3793

# %%
tracks2 = json_normalize(all_tracks)
tracks2
# Out:
#                   added_at  is_local  ... track.is_local video_thumbnail.url
# 0     2024-04-22T04:29:18Z     False  ...          False                None
# 1     2024-04-22T04:52:04Z     False  ...          False                None
# 2     2024-04-30T04:54:33Z     False  ...          False                None
# 3     2024-04-30T04:38:52Z     False  ...          False                None
# 4     2024-04-22T04:16:27Z     False  ...          False                None
# ...                    ...       ...  ...            ...                 ...
# 3788  2021-02-17T15:10:03Z     False  ...          False                None
# 3789  2021-08-16T15:30:11Z     False  ...          False                None
# 3790  2021-12-12T00:58:16Z     False  ...          False                None
# 3791  2022-03-30T17:35:03Z     False  ...          False                None
# 3792  2023-10-30T16:09:52Z     False  ...          False                None
#
# [3793 rows x 40 columns]

# %%
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] # same for popularity   
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
df_final2 = artists_df2[['song_name', 'name', 'song_id', 'popularity']]
df_final2
# Out:
#                           song_name               name                 song_id popularity
# 0                 its different now         Futuristic  6H5TYO99H0twhaMrtAHjoK         41
# 1                 its different now              Phora  6H5TYO99H0twhaMrtAHjoK         41
# 0                       Parted Ways     Arizona Zervas  3Sx8k6SH4gqMMjS7nqLcJR         46
# 1                       Parted Ways               Arye  3Sx8k6SH4gqMMjS7nqLcJR         46
# 0                         Car Radio  Twenty One Pilots  5cbpoIu3YjoOwbBDGUEp3P         70
# ..                              ...                ...                     ...        ...
# 0                            BARBIE       Young luiizy  1JRVZtipJolVoYBsF4I1B3          2
# 1                            BARBIE         Classified  1JRVZtipJolVoYBsF4I1B3          2
# 0   Uncut Gems (with MarcLo & KYLE)         THE WHALES  1F2h2ILP8mhtWV18ZY2YXY         15
# ...

# %%
chunks = [(i, i+100) for i in range(0, len(df_final2), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final2['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 5821

# %%
audio_features_df = json_normalize(audio_features_list)
audio_features_df.drop_duplicates(inplace=True) 
df_w_audio_ft = pd.merge(left=df_final2,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
# Out:
#                             song_name               name  ... duration_ms time_signature
# 0                   its different now         Futuristic  ...      202326              4
# 1                   its different now              Phora  ...      202326              4
# 2                         Parted Ways     Arizona Zervas  ...      205714              4
# 3                         Parted Ways               Arye  ...      205714              4
# 4                           Car Radio  Twenty One Pilots  ...      267720              4
# ...                               ...                ...  ...         ...            ...
# 5816                           BARBIE       Young luiizy  ...      221074              4
# 5817                           BARBIE         Classified  ...      221074              4
# 5818  Uncut Gems (with MarcLo & KYLE)         THE WHALES  ...      140446              4
# ...

# %%
#ll use our 'first paid music' playlist as an example:
playlist1 = sp.user_playlist_tracks("spotify", "4afyc6sH6wQEfTUksWzWai") 
playlist1["total"]
# Out:
# 1040

# %%
all_tracks1= get_playlist_tracks("4afyc6sH6wQEfTUksWzWai")
tracks3 = json_normalize(all_tracks1)

# %%
artists_df3 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks3.index:
    artists_for_song = json_normalize(tracks3.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks3.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks3.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks3.iloc[i]['track.popularity'] # same for popularity   
    artists_df3 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
df_final3 = artists_df3[['song_name', 'name', 'song_id', 'popularity']]
# Out:
#                    song_name                 name                 song_id popularity
# 0   100 Flower Power Maximum              Cracker  51rk0BfOr72bKW3HHrmOgd         13
# 0                         19             Old 97's  2oMqPviaYJMlEiThLWspYW         21
# 0                         29         Gin Blossoms  0h2eP1Lv0WmWzNba6l9GnC         37
# 0              The '59 Sound  The Gaslight Anthem  4T1PtJLCbe7MIsvhQZURXL          0
# 0                      Alive            Pearl Jam  1L94M3KIu7QluZe63g64rv         75
# ..                       ...                  ...                     ...        ...
# 0          I Want Everything              Cracker  5CzUivxoGJOqLQcRWRiiXh         24
# 0             I Ride My Bike              Cracker  0W9Vzc7vm32UdZXVHhBbXP         16
# 0           Trouble’s Coming          Royal Blood  6voIJ7OWwRabSZDC77D5Hp         57
# 0               Like a Stone           Audioslave  3YuaBvuZqcwN3CEAyyoaei         78
# ...

# %%
chunks = [(i, i+100) for i in range(0, len(df_final3), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final3['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
audio_features_df = json_normalize(audio_features_list)
audio_features_df.drop_duplicates(inplace=True) 
df_w_audio_ft2 = pd.merge(left=df_final3,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')

# %%
#ll use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "0Ncor000gD8vERjgIcjQ10") 
playlist["total"]
# Out:
# 807

# %%
all_tracks= get_playlist_tracks("0Ncor000gD8vERjgIcjQ10")
tracks2 = json_normalize(all_tracks)
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] # same for popularity   
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
df_final4 = artists_df2[['song_name', 'name', 'song_id', 'popularity']]
df_final4
# Out:
#                             song_name           name                 song_id popularity
# 0                          Take on Me           a-ha  2WfaOiMkCvy7F5fcp2zZ8L         88
# 0                 The Final Countdown         Europe  1li0jGGRIaMaNNRBV8JXZ4          0
# 0        Rock the Casbah - Remastered      The Clash  56KqaFSGTb7ifpt16t5Y1N         71
# 0    I Believe in a Thing Called Love   The Darkness  756CJtQRFSxEx9jV4P9hpA         70
# 0   You Spin Me Round (Like a Record)  Dead Or Alive  0BB9eUBBaaX6GALSYNcEp7          0
# ..                                ...            ...                     ...        ...
# 0           Jealous (I Ain't With It)        Chromeo  0CaHZUniQtDRZleX6XK9p7         45
# 0                          Discoproof        La Roux  0CQcUsyDEfKsHWDDF3h2C1         46
# 1                          Discoproof        Chromeo  0CQcUsyDEfKsHWDDF3h2C1         46
# 0                          I Need You         Room 5  4XZmqEoBdCKSCIgKND32by         32
# ...

# %%
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final4['song_id'][chunk[0]:chunk[1]]
    # Filter out None and NaN values from id_list100
    id_list100 = id_list100.dropna().tolist()
    # Check if id_list100 is not empty
    if id_list100:
        audio_features_list.extend(sp.audio_features(id_list100))
        sleep(randint(1, 3000) / 1000)
audio_features_df = json_normalize(audio_features_list)
audio_features_df.drop_duplicates(inplace=True) 
df_w_audio_ft3 = pd.merge(left=df_final4,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')

# %%
#ll use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "4JTrhcEuX81kdYbLFmjD2S") 
playlist["total"]
# Out:
# 541

# %%
all_tracks= get_playlist_tracks("4JTrhcEuX81kdYbLFmjD2S")
tracks2 = json_normalize(all_tracks)
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] # same for popularity   
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)

# %%
df_final5 = artists_df2[['song_name', 'name', 'song_id', 'popularity']]
df_final5
# Out:
#             song_name               name                 song_id popularity
# 0         Dream Alone  NateWantsToBattle  4IKAgNtxUv8XzX42Hhrz3r         33
# 0    Paid in Exposure  NateWantsToBattle  2QcSEZ3aq2WusXOHTo7Ife         32
# 0     Sleight of Hand  NateWantsToBattle  1fvEWyJUoUcVWNAswig4jo         31
# 0      Smoke and Guns  NateWantsToBattle  36SF0nHL9x6DowLbJHOrBk         38
# 0           All I See  NateWantsToBattle  2UEeT6XgHkaFvVsMfWeJj9         32
# ..                ...                ...                     ...        ...
# 1               Smile      Gloria Carter  2tqoJQbv6dNNOi0PCCjuse         50
# 0                 Bam              JAY-Z  6Iuh3vNjpWhSeHM3RZgzQL         55
# 1                 Bam      Damian Marley  6Iuh3vNjpWhSeHM3RZgzQL         55
# 0   Caught Their Eyes              JAY-Z  71oM9w2BbJxzTpxzWIE0lw         55
# 1   Caught Their Eyes        Frank Ocean  71oM9w2BbJxzTpxzWIE0lw         55
#
# [686 rows x 4 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final5), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final5['song_id'][chunk[0]:chunk[1]]
    id_list100 = id_list100.dropna().tolist()
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
audio_features_df = json_normalize(audio_features_list)
audio_features_df.drop_duplicates(inplace=True) 
df_w_audio_ft4 = pd.merge(left=df_final5,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')

# %%
#ll use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "5hPXWJOGl0tLvXhvT6Pgz3") 
playlist["total"]
# Out:
# 1212

# %%
all_tracks= get_playlist_tracks("5hPXWJOGl0tLvXhvT6Pgz3")
tracks2 = json_normalize(all_tracks)
artists_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] # same for popularity   
    artists_df2 = pd.concat([artists_df2, artists_for_song], axis=0)
df_final6 = artists_df2[['song_name', 'name', 'song_id', 'popularity']]
df_final6
# Out:
#                                    song_name                        name                 song_id popularity
# 0                                    Need It                       Migos  6mtjo5kIHKlboGE84lf1FJ         69
# 1                                    Need It  YoungBoy Never Broke Again  6mtjo5kIHKlboGE84lf1FJ         69
# 0   Not A Rapper (feat. Lil Baby & Yo Gotti)                     42 Dugg  0qnHywpYq7D2SGMpuHEasL          0
# 1   Not A Rapper (feat. Lil Baby & Yo Gotti)                    Lil Baby  0qnHywpYq7D2SGMpuHEasL          0
# 2   Not A Rapper (feat. Lil Baby & Yo Gotti)                    Yo Gotti  0qnHywpYq7D2SGMpuHEasL          0
# ..                                       ...                         ...                     ...        ...
# 0                                      WTFYM                      Future  1xwvjqcwflD2NEqRCNcCo2         73
# 1                                      WTFYM                Metro Boomin  1xwvjqcwflD2NEqRCNcCo2         73
# ...

# %%
chunks = [(i, i+100) for i in range(0, len(df_final6), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final6['song_id'][chunk[0]:chunk[1]]
    id_list100 = id_list100.dropna().tolist()
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
audio_features_df = json_normalize(audio_features_list)
audio_features_df.drop_duplicates(inplace=True) 
df_w_audio_ft5 = pd.merge(left=df_final6,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')

# %%
df = pd.concat([df_w_audio_ft, df_w_audio_ft2, df_w_audio_ft3, df_w_audio_ft4, df_w_audio_ft5], axis=0)

# %%
df
# Out:
#               song_name               name  ... duration_ms time_signature
# 0     its different now         Futuristic  ...      202326              4
# 1     its different now              Phora  ...      202326              4
# 2           Parted Ways     Arizona Zervas  ...      205714              4
# 3           Parted Ways               Arye  ...      205714              4
# 4             Car Radio  Twenty One Pilots  ...      267720              4
# ...                 ...                ...  ...         ...            ...
# 2160              WTFYM             Future  ...      292600              4
# 2161              WTFYM       Metro Boomin  ...      292600              4
# 2162    Crocodile Tearz            J. Cole  ...      229187              4
# 2163    Huntin’ Wabbitz            J. Cole  ...      162027              4
# 2164           Push Ups              Drake  ...      232774              4
#
# [10628 rows x 22 columns]

# %%
#df.drop(columns=["index"], inplace=True)
df.columns
# Out:
# Index(['song_name', 'name', 'song_id', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.to_csv('spotify_playlist.csv', index=False)
